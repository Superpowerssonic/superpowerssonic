# %% [markdown]
# ## Matplotlib Quiz

# %%
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False
data = {
    '영화' : ['명량', '극한직업', '신과함께-죄와 벌', '국제시장', '괴물', '도둑들', '7번방의 선물', '암살'],
    '개봉 연도' : [2014, 2019, 2017, 2014, 2006, 2012, 2013, 2015],
    '관객 수' : [1761, 1626, 1441, 1426, 1301, 1298, 1281, 1270], # (단위 : 만 명)
    '평점' : [8.88, 9.20, 8.73, 9.16, 8.62, 7.64, 8.83, 9.10]
}
df = pd.DataFrame(data)
df
# Out:
#           영화  개봉 연도  관객 수    평점
# 0         명량   2014  1761  8.88
# 1       극한직업   2019  1626  9.20
# 2  신과함께-죄와 벌   2017  1441  8.73
# 3       국제시장   2014  1426  9.16
# 4         괴물   2006  1301  8.62
# 5        도둑들   2012  1298  7.64
# 6    7번방의 선물   2013  1281  8.83
# 7         암살   2015  1270  9.10

# %% [markdown]
# ### 1)영화 데이터를 활용하여 x 축은 영화, y축은 평점인 막대 그래프를 만드시오

# %%
plt.bar(df['영화'],df['평점'])
plt.title('국내 영화 top8 정보')
plt.grid(axis='y')
plt.xticks(rotation=90)
plt.xlabel('영화')
plt.ylabeㅣ('평점')
plt.bar
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 5
#       3 plt.grid(axis='y')
#       4 plt.xticks(rotation=90)
# ----> 5 plt.xlabel('영화')
#       6 plt.ylabeㅣ('평점')
#       7 plt.bar
#
# TypeError: 'str' object is not callable

# %% [markdown]
# ### 2) 앞에서 만든 막대 그래프에 제시된 세부 사항을 적용하시오
# - 제목 : 국내 top8 영화정보
# - x 축 : 영화(90도 회전)
# - y 축 : 평점

# %% [markdown]
# ### 3) 개봉 연도별 평점 변화추이를 꺾은선 그래프로 출력하시오

# %%
df_group = df.groupby('개봉 연도').mean()
df_group

plt.plot(df_group.index, df_group['평점'])
# Out:
# C:\Users\com\AppData\Local\Temp\ipykernel_20816\2584236152.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_group = df.groupby('개봉 연도').mean()

# %% [markdown]
# ### 4) 앞에서 만든 그래프에 제시된 세부 사항을 적용하시오
# - x 축 눈금 : 5년 단위 (2005,2010,2015,2020)
# - y 축 범위 : 최소 7, 최대 10
# - marker = o

# %%
df_group = df.groupby('개봉 연도').mean()
df_group

plt.plot(df_group.index, df_group['평점'],marker='o')
plt.ylim(7,10)
plt.xticks([2005,2010,2015,2020])
# Out:
# C:\Users\com\AppData\Local\Temp\ipykernel_20816\3724388957.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_group = df.groupby('개봉 연도').mean()
# ([<matplotlib.axis.XTick at 0x2b732702410>,
# ...
#  [Text(2005, 0, '2005'),
#   Text(2010, 0, '2010'),
#   Text(2015, 0, '2015'),
#   Text(2020, 0, '2020')])

# %% [markdown]
# ### 5) 평점이 9점 이상인 영화의 비율을 확인할 수 있는 원 그래프를 제시된 세부 사항을 적용하여 그리시오
# - label : 9점 이상 / 9점 미만
# - 퍼센트 : 소수점 첫째자리까지 표시
# - 범례 : 그래프 우측에 표시

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # window
# matplotlib.rcParams['font.family'] = 'Apple Gothic' # mac
matplotlib.rcParams['font.size'] = 15 # 글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False # 음수가 깨지는 현상 방지

# %%
filt = df['평점'] >= 9
values = [len(df[filt]), len(df[~filt])] # filter에 해당하는 데이터 갯수 구하려면 len() 형태로
labels = ['9점 이상','9점 미만']
plt.pie(values, labels=labels, autopct='%.1f%%')
plt.legend(loc=(1,0.3))
plt.pie
# Out:
# <function matplotlib.pyplot.pie(x, explode=None, labels=None, colors=None, autopct=None, pctdistance=0.6, shadow=False, labeldistance=1.1, startangle=0, radius=1, counterclock=True, wedgeprops=None, textprops=None, center=(0, 0), frame=False, rotatelabels=False, *, normalize=True, hatch=None, data=None)>
